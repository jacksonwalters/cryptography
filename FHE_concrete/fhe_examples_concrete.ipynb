# %%
from concrete import fhe

# %%
#define a basic addition function
def add(x, y):
    return x + y

# %%
#define the compiler
compiler = fhe.Compiler(add, {"x": "encrypted", "y": "encrypted"})

# %%
#define an input set so the compiler knows roughly what the input widths should be
inputset = [(2, 3), (0, 0), (1, 6), (7, 7), (7, 1), (3, 2), (6, 1), (1, 7), (4, 5), (5, 4)]

# %%
print(f"Compilation...")
circuit = compiler.compile(inputset)
# Out:
# Compilation...

# %%
print(f"Key generation...")
circuit.keygen()
# Out:
# Key generation...

# %%
print(f"Homomorphic evaluation...")
encrypted_x, encrypted_y = circuit.encrypt(2, 6)
encrypted_result = circuit.run(encrypted_x, encrypted_y)
result = circuit.decrypt(encrypted_result)
# Out:
# Homomorphic evaluation...

# %%
assert result == add(2, 6)

# %%
#manage keys
serialized_keys: bytes = circuit.keys.serialize()

# %%
print(serialized_keys)
# Out:
# b'\x00\x00\x00\x00\x13\x02\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x04\x00\x00\x00\x00\x00\x03\x00\x18\x00\x00\x00\x00\x00\x01\x00\t\x00\x00\x00\x07\x00\x00\x00\t\x00\x00\x00\x07\x00\x00\x00\t@\
# ...

# %%
keys: fhe.Keys = fhe.Keys.deserialize(serialized_keys)

# %%
# !pwd
# Out:
# /Users/jacksonwalters/Documents/GitHub/cryptography

# %%
circuit.keys.save("/Users/jacksonwalters/Documents/GitHub/cryptography/concrete_keys")

# %%
circuit.keys.load("/Users/jacksonwalters/Documents/GitHub/cryptography/concrete_keys")
